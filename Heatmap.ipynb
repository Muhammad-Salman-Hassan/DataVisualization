# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=np.linspace(1,5,12).reshape(4,3)

# %%
sn.heatmap(data=data,annot=True,center=0,linewidths=1.1,cmap="mako",cbar=True)
# Out:
# <AxesSubplot:>

# %%
sn.heatmap(data=data,annot=True,center=0,linewidths=1.1,cmap="crest",cbar=True)
# Out:
# <AxesSubplot:>

# %%
sn.heatmap(data=data,annot=True,center=0,linewidths=1.1,cmap="viridis",cbar=True)
# Out:
# <AxesSubplot:>

# %%
data.sort_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-daa21f680972> in <module>
# ----> 1 data.sort_values()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'
